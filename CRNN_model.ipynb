# %%
import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, BatchNormalization, Lambda
from keras.layers.advanced_activations import ELU
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop

from keras import regularizers


import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load training and Validation arrays

# %%
dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 
               'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7  }


reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 2: 'Folk', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International', 6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('shuffled_train.npz')
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394, 8)

# %%
npzfile = np.load('shuffled_valid.npz')
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800, 8)

# %% [markdown]
# ### Check by plotting a Spectogram

# %%
num = 5300
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Experimental

# %% [markdown]
# ### CNN - RNN Model

# %%
batch_size = 32
num_classes = 8
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
N_LAYERS = 3
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 32
LSTM_COUNT = 96
EPOCH_COUNT = 70
NUM_HIDDEN = 64
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = Conv1D(
                filters=CONV_FILTER_COUNT,
                kernel_size=FILTER_LENGTH,
                kernel_regularizer=regularizers.l2(L2_regularization),  # Tried 0.001
                name='convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum=0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.4)(layer)
    
    ## LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences=False)(layer)
    layer = Dropout(0.4)(layer)
    
    ## Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
    layer = Dropout(0.4)(layer)
    
    ## Softmax Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name='output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    
    opt = Adam(lr=0.001)
    model.compile(
            loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/crnn/weights.best.h5', monitor='val_acc', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(
                monitor='val_acc', factor=0.5, patience=10, min_delta=0.01,
                verbose=1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, None, 128)         0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization_4 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_4 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_5 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_5 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_6 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_6 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 520
# _________________________________________________________________
# output_realtime (Activation) (None, 8)                 0
# =================================================================
# Total params: 133,520
# Trainable params: 133,184
# Non-trainable params: 336
# _________________________________________________________________
# None
# Training...
# Train on 6394 samples, validate on 800 samples
# Epoch 1/70
# 6394/6394 [==============================] - 14s 2ms/step - loss: 2.1489 - acc: 0.2732 - val_loss: 2.1627 - val_acc: 0.2450
#
# Epoch 00001: val_acc improved from -inf to 0.24500, saving model to ./models/crnn/weights.best.h5
# Epoch 2/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.9868 - acc: 0.3517 - val_loss: 2.1041 - val_acc: 0.2975
#
# Epoch 00002: val_acc improved from 0.24500 to 0.29750, saving model to ./models/crnn/weights.best.h5
# Epoch 3/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.9252 - acc: 0.3735 - val_loss: 2.0258 - val_acc: 0.2775
#
# Epoch 00003: val_acc did not improve from 0.29750
# Epoch 4/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.8681 - acc: 0.3840 - val_loss: 2.1284 - val_acc: 0.2712
#
# Epoch 00004: val_acc did not improve from 0.29750
# Epoch 5/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.8222 - acc: 0.3982 - val_loss: 2.2019 - val_acc: 0.3163
#
# Epoch 00005: val_acc improved from 0.29750 to 0.31625, saving model to ./models/crnn/weights.best.h5
# Epoch 6/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.7835 - acc: 0.4132 - val_loss: 1.8148 - val_acc: 0.3500
#
# Epoch 00006: val_acc improved from 0.31625 to 0.35000, saving model to ./models/crnn/weights.best.h5
# Epoch 7/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.7534 - acc: 0.4191 - val_loss: 2.1124 - val_acc: 0.2938
#
# Epoch 00007: val_acc did not improve from 0.35000
# Epoch 8/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.7400 - acc: 0.4309 - val_loss: 1.8739 - val_acc: 0.3650
#
# Epoch 00008: val_acc improved from 0.35000 to 0.36500, saving model to ./models/crnn/weights.best.h5
# Epoch 9/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.7072 - acc: 0.4382 - val_loss: 1.8210 - val_acc: 0.3788
#
# Epoch 00009: val_acc improved from 0.36500 to 0.37875, saving model to ./models/crnn/weights.best.h5
# Epoch 10/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.6989 - acc: 0.4395 - val_loss: 2.2063 - val_acc: 0.2462
#
# Epoch 00010: val_acc did not improve from 0.37875
# Epoch 11/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.6564 - acc: 0.4567 - val_loss: 2.1774 - val_acc: 0.2550
#
# Epoch 00011: val_acc did not improve from 0.37875
# Epoch 12/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.6595 - acc: 0.4620 - val_loss: 2.0643 - val_acc: 0.3038
#
# Epoch 00012: val_acc did not improve from 0.37875
# Epoch 13/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.6236 - acc: 0.4695 - val_loss: 2.2976 - val_acc: 0.2400
#
# Epoch 00013: val_acc did not improve from 0.37875
# Epoch 14/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.6143 - acc: 0.4811 - val_loss: 2.3238 - val_acc: 0.2725
#
# Epoch 00014: val_acc did not improve from 0.37875
# Epoch 15/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.5956 - acc: 0.4865 - val_loss: 2.3019 - val_acc: 0.3100
#
# Epoch 00015: val_acc did not improve from 0.37875
# Epoch 16/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.5832 - acc: 0.4912 - val_loss: 1.9966 - val_acc: 0.3387
#
# Epoch 00016: val_acc did not improve from 0.37875
# Epoch 17/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.5668 - acc: 0.5014 - val_loss: 2.0489 - val_acc: 0.3238
#
# Epoch 00017: val_acc did not improve from 0.37875
# Epoch 18/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.5554 - acc: 0.5088 - val_loss: 2.2051 - val_acc: 0.3137
#
# Epoch 00018: val_acc did not improve from 0.37875
# Epoch 19/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.5496 - acc: 0.5058 - val_loss: 2.2395 - val_acc: 0.3100
#
# Epoch 00019: val_acc did not improve from 0.37875
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.4824 - acc: 0.5317 - val_loss: 1.7361 - val_acc: 0.3863
#
# Epoch 00020: val_acc improved from 0.37875 to 0.38625, saving model to ./models/crnn/weights.best.h5
# Epoch 21/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.4532 - acc: 0.5424 - val_loss: 2.0617 - val_acc: 0.3950
#
# Epoch 00021: val_acc improved from 0.38625 to 0.39500, saving model to ./models/crnn/weights.best.h5
# Epoch 22/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.4395 - acc: 0.5486 - val_loss: 1.7212 - val_acc: 0.4238
#
# Epoch 00022: val_acc improved from 0.39500 to 0.42375, saving model to ./models/crnn/weights.best.h5
# Epoch 23/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.4187 - acc: 0.5554 - val_loss: 2.5678 - val_acc: 0.3238
#
# Epoch 00023: val_acc did not improve from 0.42375
# Epoch 24/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.4170 - acc: 0.5500 - val_loss: 1.8982 - val_acc: 0.3925
#
# Epoch 00024: val_acc did not improve from 0.42375
# Epoch 25/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3894 - acc: 0.5621 - val_loss: 1.8156 - val_acc: 0.4062
#
# Epoch 00025: val_acc did not improve from 0.42375
# Epoch 26/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3795 - acc: 0.5657 - val_loss: 1.9587 - val_acc: 0.3762
#
# Epoch 00026: val_acc did not improve from 0.42375
# Epoch 27/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3780 - acc: 0.5657 - val_loss: 1.8303 - val_acc: 0.3925
#
# Epoch 00027: val_acc did not improve from 0.42375
# Epoch 28/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3793 - acc: 0.5704 - val_loss: 1.6929 - val_acc: 0.4437
#
# Epoch 00028: val_acc improved from 0.42375 to 0.44375, saving model to ./models/crnn/weights.best.h5
# Epoch 29/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3729 - acc: 0.5651 - val_loss: 1.7630 - val_acc: 0.4025
#
# Epoch 00029: val_acc did not improve from 0.44375
# Epoch 30/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3459 - acc: 0.5729 - val_loss: 1.8257 - val_acc: 0.4037
#
# Epoch 00030: val_acc did not improve from 0.44375
# Epoch 31/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3476 - acc: 0.5763 - val_loss: 1.8997 - val_acc: 0.4100
#
# Epoch 00031: val_acc did not improve from 0.44375
# Epoch 32/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3444 - acc: 0.5757 - val_loss: 2.1644 - val_acc: 0.3788
#
# Epoch 00032: val_acc did not improve from 0.44375
# Epoch 33/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3221 - acc: 0.5780 - val_loss: 1.7429 - val_acc: 0.4288
#
# Epoch 00033: val_acc did not improve from 0.44375
# Epoch 34/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3248 - acc: 0.5826 - val_loss: 1.9436 - val_acc: 0.4150
#
# Epoch 00034: val_acc did not improve from 0.44375
# Epoch 35/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3022 - acc: 0.5896 - val_loss: 1.8905 - val_acc: 0.3488
#
# Epoch 00035: val_acc did not improve from 0.44375
# Epoch 36/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3113 - acc: 0.5891 - val_loss: 1.9178 - val_acc: 0.3663
#
# Epoch 00036: val_acc did not improve from 0.44375
# Epoch 37/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.3050 - acc: 0.5956 - val_loss: 1.7960 - val_acc: 0.4100
#
# Epoch 00037: val_acc did not improve from 0.44375
# Epoch 38/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.2935 - acc: 0.5987 - val_loss: 1.9050 - val_acc: 0.4225
#
# Epoch 00038: val_acc did not improve from 0.44375
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 39/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.2463 - acc: 0.6062 - val_loss: 1.4988 - val_acc: 0.5138
#
# Epoch 00039: val_acc improved from 0.44375 to 0.51375, saving model to ./models/crnn/weights.best.h5
# Epoch 40/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.2200 - acc: 0.6231 - val_loss: 1.5822 - val_acc: 0.4925
#
# Epoch 00040: val_acc did not improve from 0.51375
# Epoch 41/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.2177 - acc: 0.6179 - val_loss: 1.6566 - val_acc: 0.4512
#
# Epoch 00041: val_acc did not improve from 0.51375
# Epoch 42/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.2105 - acc: 0.6279 - val_loss: 1.6140 - val_acc: 0.4775
#
# Epoch 00042: val_acc did not improve from 0.51375
# Epoch 43/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1944 - acc: 0.6297 - val_loss: 1.8310 - val_acc: 0.4262
#
# Epoch 00043: val_acc did not improve from 0.51375
# Epoch 44/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.2047 - acc: 0.6268 - val_loss: 1.6349 - val_acc: 0.4662
#
# Epoch 00044: val_acc did not improve from 0.51375
# Epoch 45/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1778 - acc: 0.6329 - val_loss: 2.3707 - val_acc: 0.3688
#
# Epoch 00045: val_acc did not improve from 0.51375
# Epoch 46/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1771 - acc: 0.6306 - val_loss: 1.7384 - val_acc: 0.4700
#
# Epoch 00046: val_acc did not improve from 0.51375
# Epoch 47/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1956 - acc: 0.6268 - val_loss: 1.7262 - val_acc: 0.5050
#
# Epoch 00047: val_acc did not improve from 0.51375
# Epoch 48/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1645 - acc: 0.6409 - val_loss: 1.8173 - val_acc: 0.4650
#
# Epoch 00048: val_acc did not improve from 0.51375
# Epoch 49/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1671 - acc: 0.6397 - val_loss: 1.8505 - val_acc: 0.4350
#
# Epoch 00049: val_acc did not improve from 0.51375
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 50/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1310 - acc: 0.6514 - val_loss: 1.5618 - val_acc: 0.4950
#
# Epoch 00050: val_acc did not improve from 0.51375
# Epoch 51/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1161 - acc: 0.6522 - val_loss: 1.8317 - val_acc: 0.4562
#
# Epoch 00051: val_acc did not improve from 0.51375
# Epoch 52/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1121 - acc: 0.6628 - val_loss: 1.7533 - val_acc: 0.4587
#
# Epoch 00052: val_acc did not improve from 0.51375
# Epoch 53/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1170 - acc: 0.6514 - val_loss: 1.8781 - val_acc: 0.4775
#
# Epoch 00053: val_acc did not improve from 0.51375
# Epoch 54/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.1039 - acc: 0.6541 - val_loss: 1.6430 - val_acc: 0.5050
#
# Epoch 00054: val_acc did not improve from 0.51375
# Epoch 55/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0895 - acc: 0.6614 - val_loss: 1.6002 - val_acc: 0.4763
#
# Epoch 00055: val_acc did not improve from 0.51375
# Epoch 56/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0882 - acc: 0.6625 - val_loss: 1.6637 - val_acc: 0.4575
#
# Epoch 00056: val_acc did not improve from 0.51375
# Epoch 57/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0970 - acc: 0.6625 - val_loss: 1.6481 - val_acc: 0.4713
#
# Epoch 00057: val_acc did not improve from 0.51375
# Epoch 58/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0915 - acc: 0.6578 - val_loss: 1.6052 - val_acc: 0.5062
#
# Epoch 00058: val_acc did not improve from 0.51375
# Epoch 59/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0978 - acc: 0.6622 - val_loss: 2.1387 - val_acc: 0.3912
#
# Epoch 00059: val_acc did not improve from 0.51375
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 60/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0668 - acc: 0.6703 - val_loss: 1.6285 - val_acc: 0.4825
#
# Epoch 00060: val_acc did not improve from 0.51375
# Epoch 61/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0625 - acc: 0.6708 - val_loss: 1.6316 - val_acc: 0.4738
#
# Epoch 00061: val_acc did not improve from 0.51375
# Epoch 62/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0640 - acc: 0.6739 - val_loss: 1.6124 - val_acc: 0.4887
#
# Epoch 00062: val_acc did not improve from 0.51375
# Epoch 63/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0440 - acc: 0.6808 - val_loss: 1.5988 - val_acc: 0.5062
#
# Epoch 00063: val_acc did not improve from 0.51375
# Epoch 64/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0569 - acc: 0.6775 - val_loss: 1.6567 - val_acc: 0.4763
#
# Epoch 00064: val_acc did not improve from 0.51375
# Epoch 65/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0479 - acc: 0.6825 - val_loss: 1.6371 - val_acc: 0.4825
#
# Epoch 00065: val_acc did not improve from 0.51375
# Epoch 66/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0337 - acc: 0.6863 - val_loss: 1.6404 - val_acc: 0.5000
#
# Epoch 00066: val_acc did not improve from 0.51375
# Epoch 67/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0578 - acc: 0.6747 - val_loss: 1.5557 - val_acc: 0.5062
#
# Epoch 00067: val_acc did not improve from 0.51375
# Epoch 68/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0505 - acc: 0.6766 - val_loss: 1.6600 - val_acc: 0.4863
#
# Epoch 00068: val_acc did not improve from 0.51375
# Epoch 69/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0420 - acc: 0.6814 - val_loss: 1.6452 - val_acc: 0.4913
#
# Epoch 00069: val_acc did not improve from 0.51375
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 70/70
# 6394/6394 [==============================] - 13s 2ms/step - loss: 1.0328 - acc: 0.6874 - val_loss: 1.5554 - val_acc: 0.4988
#
# Epoch 00070: val_acc did not improve from 0.51375

# %%
show_summary_stats(history)
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'lr'])

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_valid, axis = 1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.51      0.40      0.45       100
#  Experimental       0.48      0.58      0.53       100
#          Folk       0.69      0.68      0.69       100
#       Hip-Hop       0.64      0.59      0.61       100
#  Instrumental       0.49      0.35      0.41       100
# International       0.59      0.65      0.62       100
#           Pop       0.15      0.20      0.17       100
#          Rock       0.55      0.54      0.55       100
#
#     micro avg       0.50      0.50      0.50       800
#     macro avg       0.51      0.50      0.50       800
#  weighted avg       0.51      0.50      0.50       800

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.49875

# %% [markdown]
# ### Connect to Test Set

# %%
from keras.models import load_model

weights_path = 'models/crnn/weights.best.h5'
model = load_model(weights_path)
# Out:
# WARNING:tensorflow:From /home/priya/miniconda3/envs/exptt/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead

# %%
npzfile = np.load('test_arr.npz')
print(npzfile.files)
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_test -= 1
print(np.amin(y_test), np.amax(y_test), np.mean(y_test))
# Out:
# 0 7 3.5

# %%
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0000000000000016 0.004623813018385694

# %%
X_test = np.log(X_test_raw)


from sklearn.metrics import classification_report

y_true = y_test
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.64      0.49      0.55       100
#  Experimental       0.28      0.22      0.25       100
#          Folk       0.19      0.16      0.17       100
#       Hip-Hop       0.57      0.85      0.68       100
#  Instrumental       0.36      0.34      0.35       100
# International       0.46      0.64      0.54       100
#           Pop       0.30      0.27      0.28       100
#          Rock       0.64      0.56      0.60       100
#
#     micro avg       0.44      0.44      0.44       800
#     macro avg       0.43      0.44      0.43       800
#  weighted avg       0.43      0.44      0.43       800

# %%
y_test = keras.utils.to_categorical(y_test, num_classes=8)
model.evaluate(X_test, y_test)
# Out:
# 800/800 [==============================] - 1s 707us/step
# [1.7413653707504273, 0.44125]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_true, y_pred))
# Out:
# [[49  1  6 16  5 13  8  2]
#  [ 9 22  8  9 21 17  7  7]
#  [ 0 27 16  1 17 14 19  6]
#  [ 3  2  1 85  1  6  2  0]
#  [ 3 18 29  1 34  8  5  2]
#  [ 3  1 10  9  3 64  6  4]
#  [ 7  2  9 28  4 12 27 11]
#  [ 3  6  4  1  9  4 17 56]]

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.44125

# %%
### 8 clusters
from sklearn.metrics import confusion_matrix
import seaborn as sns


mat = confusion_matrix(y_true, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=dict_genres.keys(),
            yticklabels=dict_genres.keys())
plt.xlabel('true label')
plt.ylabel('predicted label');
